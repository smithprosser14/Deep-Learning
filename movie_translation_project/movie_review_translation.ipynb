# %% [markdown]
# # Text Translation and Sentiment Analysis using Transformers

# %% [markdown]
# ## Project Overview:
#
# The objective of this project is to analyze the sentiment of movie reviews in three different languages - English, French, and Spanish. There are a total of 30 movies, 10 in each language, along with their reviews and synopses. The data was provided in 3 separate CSV files named `movie_reviews_eng.csv`, `movie_reviews_fr.csv`, and `movie_reviews_sp.csv`.
#
# The aim of this project will be to input a dataframe in a given language of choice - and the result will be the data translated into english (if not in english originally) and the sentiment of the reviews analysed.

# %%
# imports
from pathlib import Path
import sys

ROOT_DIR = Path.cwd()
sys.path.append(ROOT_DIR)

import pandas as pd
from translator import Translator
from transformers import AutoModelForSequenceClassification, AutoTokenizer

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Creating Translator Class

# %% [markdown]
# ### Get data from `.csv` files and then preprocess data

# %%
sp_translator = Translator("data/movie_reviews_sp.csv")
translated_sp = sp_translator.translate()
# Out:
# Original Language: ES

# %%
sp_translator.original_df
# Out:
#                                 Title         Year  \
# 0                                Roma         2018
# 1                    La Casa de Papel  (2017-2021)
# 2                   Y tu mamá también         2001
# 3              El Laberinto del Fauno         2006
# 4                       Amores perros         2000
# 5                        Águila Roja   (2009-2016)
# 6                             Toc Toc         2017
# 7                              El Bar         2017
# 8  Torrente: El brazo tonto de la ley         1998
# 9                        El Incidente         2014
#
#                                             Synopsis  \
# 0  Cleo (Yalitza Aparicio) es una joven empleada ...
# 1  Esta serie de televisión española sigue a un g...
# 2  Dos amigos adolescentes (Gael García Bernal y ...
# 3  Durante la posguerra española, Ofelia (Ivana B...
# 4  Tres historias se entrelazan en esta película ...
# 5  Esta serie de televisión española sigue las av...
# 6  En esta comedia española, un grupo de personas...
# 7  Un grupo de personas quedan atrapadas en un ba...
# 8  En esta comedia española, un policía corrupto ...
# 9  En esta película de terror mexicana, un grupo ...
#
#                                               Review
# 0  "Roma es una película hermosa y conmovedora qu...
# 1  "La Casa de Papel es una serie emocionante y a...
# 2  "Y tu mamá también es una película que se qued...
# 3  "El Laberinto del Fauno es una película fascin...
# 4  "Amores perros es una película intensa y conmo...
# 5  "Águila Roja es una serie aburrida y poco inte...
# 6  "Toc Toc es una película aburrida y poco origi...
# 7  "El Bar es una película ridícula y sin sentido...
# 8  "Torrente es una película vulgar y ofensiva qu...
# 9  "El Incidente es una película aburrida y sin s...

# %%
translated_sp
# Out:
#                                 Title         Year  \
# 0                                Roma         2018
# 1                    La Casa de Papel  (2017-2021)
# 2                   Y tu mamá también         2001
# 3              El Laberinto del Fauno         2006
# 4                       Amores perros         2000
# 5                        Águila Roja   (2009-2016)
# 6                             Toc Toc         2017
# 7                              El Bar         2017
# 8  Torrente: El brazo tonto de la ley         1998
# 9                        El Incidente         2014
#
#                                             Synopsis  \
# 0  Cleo (Yalitza Aparicio) is a young domestic wo...
# 1  This Spanish television series follows a group...
# 2  Two teenage friends (Gael García Bernal and Di...
# 3  During the Spanish postwar period, Ofelia (Iva...
# 4  Three stories intertwine in this Mexican film:...
# 5  This Spanish television series follows the adv...
# 6  In this Spanish comedy, a group of people with...
# 7  A group of people are trapped in a bar after M...
# 8  In this Spanish comedy, a corrupt cop (played ...
# 9  In this Mexican horror film, a group of people...
#
#                                               Review
# 0  "Rome is a beautiful and moving film that pays...
# 1  "The Paper House is an exciting and addictive ...
# 2  "And your mom is also a movie that stays with ...
# 3  "The Labyrinth of Fauno is a fascinating and e...
# 4  "Amores dogs is an intense and moving film tha...
# 5  "Red Eagle is a boring and uninteresting serie...
# 6  "Toc Toc is a boring and unoriginal film that ...
# 7  "The Bar is a ridiculous and meaningless film ...
# 8  "Torrente is a vulgar and offensive film that ...
# 9  "The Incident is a boring and frightless film ...

# %%
fr_translator = Translator("data/movie_reviews_fr.csv")
translated_fr = fr_translator.translate()

# %%
fr_translator.original_df
# Out:
#                                  Title  Year  \
# 0                           La La Land  2016
# 1                         Intouchables  2011
# 2                               Amélie  2001
# 3                        Les Choristes  2004
# 4  Le Fabuleux Destin d'Amélie Poulain  2001
# 5                     Le Dîner de Cons  1998
# 6       La Tour Montparnasse Infernale  2001
# 7          Astérix aux Jeux Olympiques  2008
# 8            Les Visiteurs en Amérique  2000
# 9                         Babylon A.D.  2008
#
#                                             Synopsis  \
# 0  Cette comédie musicale raconte l'histoire d'un...
# 1  Ce film raconte l'histoire de l'amitié improba...
# 2  Cette comédie romantique raconte l'histoire d'...
# 3  Ce film raconte l'histoire d'un professeur de ...
# 4  Cette comédie romantique raconte l'histoire d'...
# 5  Le film suit l'histoire d'un groupe d'amis ric...
# 6  Deux employés de bureau incompétents se retrou...
# 7  Dans cette adaptation cinématographique de la ...
# 8  Dans cette suite de la comédie française Les V...
# 9  Dans un futur lointain, un mercenaire doit esc...
#
#                                               Review
# 0  "La La Land est un film absolument magnifique ...
# 1  "Intouchables est un film incroyablement touch...
# 2  "Amélie est un film absolument charmant qui vo...
# 3  "Les Choristes est un film magnifique qui vous...
# 4  "Le Fabuleux Destin d'Amélie Poulain est un fi...
# 5  "Je n'ai pas aimé ce film du tout. Le concept ...
# 6  "Je ne peux pas croire que j'ai perdu du temps...
# 7  "Ce film est une déception totale. Les blagues...
# 8  "Le film est une perte de temps totale. Les bl...
# 9  "Ce film est un gâchis complet. Les personnage...

# %%
translated_fr
# Out:
#                                  Title  Year  \
# 0                           La La Land  2016
# 1                         Intouchables  2011
# 2                               Amélie  2001
# 3                        Les Choristes  2004
# 4  Le Fabuleux Destin d'Amélie Poulain  2001
# 5                     Le Dîner de Cons  1998
# 6       La Tour Montparnasse Infernale  2001
# 7          Astérix aux Jeux Olympiques  2008
# 8            Les Visiteurs en Amérique  2000
# 9                         Babylon A.D.  2008
#
#                                             Synopsis  \
# 0  This musical tells the story of a budding actr...
# 1  This film tells the story of the unlikely frie...
# 2  This romantic comedy tells the story of Amélie...
# 3  This film tells the story of a music teacher w...
# 4  This romantic comedy tells the story of Amélie...
# 5  The film follows the story of a group of rich ...
# 6  Two incompetent office workers find themselves...
# 7  In this film adaptation of the popular comic s...
# 8  In this continuation of the French comedy The ...
# 9  In the distant future, a mercenary has to esco...
#
#                                               Review
# 0  "The Land is an absolutely beautiful film with...
# 1  "Untouchables is an incredibly touching film w...
# 2  "Amélie is an absolutely charming film that wi...
# 3  "The Choristes are a beautiful film that will ...
# 4  "The Fabulous Destiny of Amélie Poulain is an ...
# 5  "I didn't like this movie at all. The concept ...
# 6  "I can't believe I've wasted time watching thi...
# 7  "This film is a complete disappointment. The j...
# 8  "The film is a total waste of time. The jokes ...
# 9  "This film is a complete mess. The characters ...

# %% [markdown]
# ### Text translation
#
# Translate the **Review** and **Synopsis** column values to English.
#
# **MarianMT** was chosen as the translation model framework (all model names within MarianMT have the following format **Helsinki-NLP/opus-mt-{src}-{tgt}**).

# %% [markdown]
# ### Sentiment Analysis
#
# Use HuggingFace pretrained model for sentiment analysis of the reviews -storing the sentiment result **Positive** or **Negative** as a new feature titled **Sentiment**.
#
# AutoClasses can automatically retrieve the relevant model given the name/path to the pretrained weights/config/vocabulary:

# %%
# load sentiment analysis model
model_name = "distilbert/distilbert-base-uncased-finetuned-sst-2-english"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# %% [markdown]
# Pipelines are objects that offer a simple API dedicated to several tasks, including Named Entity Recognition, Masked Language Modeling, Sentiment Analysis, Feature Extraction and Question Answering.

# %%
sentiment_classifier = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# %%
def analyze_sentiment(text, classifier):
    """
    function to perform sentiment analysis on a text using a model
    """
    return classifier(text)

# %%
def analyze_movie_review(df: pd.DataFrame):
    
    df["Sentiment"] = df["Review"].apply(lambda x: analyze_sentiment(x, sentiment_classifier)[0]['label'].title())
    
    return df

# %%
analyzed_fr = analyze_movie_review(translated_fr)
analyzed_fr
# Out:
#                                  Title  Year  \
# 0                           La La Land  2016
# 1                         Intouchables  2011
# 2                               Amélie  2001
# 3                        Les Choristes  2004
# 4  Le Fabuleux Destin d'Amélie Poulain  2001
# 5                     Le Dîner de Cons  1998
# 6       La Tour Montparnasse Infernale  2001
# 7          Astérix aux Jeux Olympiques  2008
# 8            Les Visiteurs en Amérique  2000
# 9                         Babylon A.D.  2008
#
#                                             Synopsis  \
# 0  This musical tells the story of a budding actr...
# 1  This film tells the story of the unlikely frie...
# 2  This romantic comedy tells the story of Amélie...
# 3  This film tells the story of a music teacher w...
# 4  This romantic comedy tells the story of Amélie...
# 5  The film follows the story of a group of rich ...
# 6  Two incompetent office workers find themselves...
# 7  In this film adaptation of the popular comic s...
# 8  In this continuation of the French comedy The ...
# 9  In the distant future, a mercenary has to esco...
#
#                                               Review Sentiment
# 0  "The Land is an absolutely beautiful film with...  Positive
# 1  "Untouchables is an incredibly touching film w...  Positive
# 2  "Amélie is an absolutely charming film that wi...  Positive
# 3  "The Choristes are a beautiful film that will ...  Positive
# 4  "The Fabulous Destiny of Amélie Poulain is an ...  Positive
# 5  "I didn't like this movie at all. The concept ...  Negative
# 6  "I can't believe I've wasted time watching thi...  Negative
# 7  "This film is a complete disappointment. The j...  Negative
# 8  "The film is a total waste of time. The jokes ...  Negative
# 9  "This film is a complete mess. The characters ...  Negative

# %%
analyzed_sp = analyze_movie_review(translated_sp)
analyzed_sp
# Out:
#                                 Title         Year  \
# 0                                Roma         2018
# 1                    La Casa de Papel  (2017-2021)
# 2                   Y tu mamá también         2001
# 3              El Laberinto del Fauno         2006
# 4                       Amores perros         2000
# 5                        Águila Roja   (2009-2016)
# 6                             Toc Toc         2017
# 7                              El Bar         2017
# 8  Torrente: El brazo tonto de la ley         1998
# 9                        El Incidente         2014
#
#                                             Synopsis  \
# 0  Cleo (Yalitza Aparicio) is a young domestic wo...
# 1  This Spanish television series follows a group...
# 2  Two teenage friends (Gael García Bernal and Di...
# 3  During the Spanish postwar period, Ofelia (Iva...
# 4  Three stories intertwine in this Mexican film:...
# 5  This Spanish television series follows the adv...
# 6  In this Spanish comedy, a group of people with...
# 7  A group of people are trapped in a bar after M...
# 8  In this Spanish comedy, a corrupt cop (played ...
# 9  In this Mexican horror film, a group of people...
#
#                                               Review Sentiment
# 0  "Rome is a beautiful and moving film that pays...  Positive
# 1  "The Paper House is an exciting and addictive ...  Positive
# 2  "And your mom is also a movie that stays with ...  Positive
# 3  "The Labyrinth of Fauno is a fascinating and e...  Positive
# 4  "Amores dogs is an intense and moving film tha...  Positive
# 5  "Red Eagle is a boring and uninteresting serie...  Negative
# 6  "Toc Toc is a boring and unoriginal film that ...  Negative
# 7  "The Bar is a ridiculous and meaningless film ...  Negative
# 8  "Torrente is a vulgar and offensive film that ...  Negative
# 9  "The Incident is a boring and frightless film ...  Negative

# %% [markdown]
# ### Future work
# - Translation of column names to allow datasets of different features to be inputted into the model.
# - Use more advanced sentiment analyzer i.e. give a star rating.
